# %% [markdown]
# # Billionaires
#
# `conda install sqlite sqlalchemy`
#
# Source: https://corgis-edu.github.io/corgis/csv/billionaires/
#
# SQLAlchemy: https://docs.sqlalchemy.org/en/13/core/connections.html

# %%
import numpy as np
import pandas as pd

# %%
# Cargo el dataset
df = pd.read_csv('billionaires.csv', delimiter = ',')
df.head(7)
# Out:
#                       name  rank  year  company.founded          company.name  \
# 0               Bill Gates     1  1996             1975             Microsoft
# 1               Bill Gates     1  2001             1975             Microsoft
# 2               Bill Gates     1  2014             1975             Microsoft
# 3           Warren Buffett     2  1996             1962    Berkshire Hathaway
# 4           Warren Buffett     2  2001             1962    Berkshire Hathaway
# 5         Carlos Slim Helu     2  2014             1990                Telmex
# 6  Oeri Hoffman and Sacher     3  1996             1896  F. Hoffmann-La Roche
#
#   company.relationship   company.sector   company.type  demographics.age  \
# 0              founder         Software            new                40
# 1              founder         Software            new                45
# 2              founder         Software            new                58
# 3              founder          Finance            new                65
# 4              founder          Finance            new                70
# 5              founder   Communications  privatization                74
# 6                  NaN  pharmaceuticals            new                 0
#
#   demographics.gender  ...    location.gdp location.region  \
# 0                male  ...   8100000000000   North America
# 1                male  ...  10600000000000   North America
# 2                male  ...               0   North America
# 3                male  ...   8100000000000   North America
# 4                male  ...  10600000000000   North America
# 5                male  ...               0   Latin America
# 6                 NaN  ...    330000000000          Europe
#
#                 wealth.type wealth.worth in billions wealth.how.category  \
# 0       founder non-finance                     18.5         New Sectors
# 1       founder non-finance                     58.7         New Sectors
# 2       founder non-finance                     76.0         New Sectors
# 3       founder non-finance                     15.0      Traded Sectors
# 4       founder non-finance                     32.3      Traded Sectors
# 5  privatized and resources                     72.0  Non-Traded Sectors
# 6                 inherited                     13.1         New Sectors
#
#    wealth.how.from emerging  wealth.how.industry  wealth.how.inherited  \
# 0                      True  Technology-Computer         not inherited
# 1                      True  Technology-Computer         not inherited
# 2                      True  Technology-Computer         not inherited
# 3                      True             Consumer         not inherited
# 4                      True             Consumer         not inherited
# 5                      True                Media         not inherited
# 6                      True   Technology-Medical        3rd generation
#
#   wealth.how.was founder wealth.how.was political
# 0                   True                     True
# 1                   True                     True
# 2                   True                     True
# 3                   True                     True
# 4                   True                     True
# 5                   True                     True
# 6                   True                     True
#
# [7 rows x 22 columns]

# %% [markdown]
# ## All rows where company is Microsoft or Zara

# %%
df[(df['company.name'] == "Zara") | (df['company.name'] == "Microsoft")]
# Out:
#                     name  rank  year  company.founded company.name  \
# 0             Bill Gates     1  1996             1975    Microsoft
# 1             Bill Gates     1  2001             1975    Microsoft
# 2             Bill Gates     1  2014             1975    Microsoft
# 7             Paul Allen     3  2001             1975    Microsoft
# 8         Amancio Ortega     3  2014             1975         Zara
# 36            Paul Allen    13  1996             1975    Microsoft
# 37        Steven Ballmer    13  2001             1975    Microsoft
# 107        Steve Ballmer    36  2014             1975    Microsoft
# 129       Amancio Ortega    43  2001             1975         Zara
# 167           Paul Allen    56  2014             1975    Microsoft
# 197       Steven Ballmer    66  1996             1975    Microsoft
# 690   Sandra Ortega Mera   227  2014             1975         Zara
# 1421     Charles Simonyi   490  2001             1975    Microsoft
# 2263     Charles Simonyi  1284  2014             1975    Microsoft
#
#                                 company.relationship company.sector  \
# 0                                            founder       Software
# 1                                            founder       Software
# 2                                            founder       Software
# 7                                            founder     technology
# 8                                            founder        Fashion
# 36                                           founder     technology
# 37                                               CEO     technology
# 107                                              CEO     technology
# 129                                          founder        Fashion
# 167                                          founder     technology
# 197                                              CEO     technology
# 690                                         relation       clothing
# 1421  head of Microsoft's application software group       software
# 2263  head of Microsoft's application software group       software
#
#      company.type  demographics.age demographics.gender  ...    location.gdp  \
# 0             new                40                male  ...   8100000000000
# 1             new                45                male  ...  10600000000000
# 2             new                58                male  ...               0
# 7             new                48                male  ...  10600000000000
# 8             new                77                male  ...               0
# 36            new                43                male  ...   8100000000000
# 37            new                44                male  ...  10600000000000
# 107           new                57                male  ...               0
# 129           new                65                male  ...    626000000000
# 167           new                61                male  ...               0
# 197           new                39                male  ...   8100000000000
# 690           new                45              female  ...               0
# 1421          new                53                male  ...  10600000000000
# 2263          new                66                male  ...               0
#
#      location.region          wealth.type wealth.worth in billions  \
# 0      North America  founder non-finance                     18.5
# 1      North America  founder non-finance                     58.7
# 2      North America  founder non-finance                     76.0
# 7      North America  founder non-finance                     30.4
# 8             Europe  founder non-finance                     64.0
# 36     North America  founder non-finance                      7.5
# 37     North America            executive                     16.6
# 107    North America            executive                     19.3
# 129           Europe  founder non-finance                      6.6
# 167    North America  founder non-finance                     15.9
# 197    North America            executive                      3.7
# 690           Europe            inherited                      6.1
# 1421   North America            executive                      1.0
# 2263   North America            executive                      1.3
#
#      wealth.how.category  wealth.how.from emerging  wealth.how.industry  \
# 0            New Sectors                      True  Technology-Computer
# 1            New Sectors                      True  Technology-Computer
# 2            New Sectors                      True  Technology-Computer
# 7            New Sectors                      True  Technology-Computer
# 8     Non-Traded Sectors                      True   Retail, Restaurant
# 36           New Sectors                      True  Technology-Computer
# 37           New Sectors                      True  Technology-Computer
# 107          New Sectors                      True  Technology-Computer
# 129       Traded Sectors                      True             Consumer
# 167          New Sectors                      True  Technology-Computer
# 197          New Sectors                      True  Technology-Computer
# 690       Traded Sectors                      True             Consumer
# 1421         New Sectors                      True  Technology-Computer
# 2263         New Sectors                      True  Technology-Computer
#
#       wealth.how.inherited wealth.how.was founder wealth.how.was political
# 0            not inherited                   True                     True
# 1            not inherited                   True                     True
# 2            not inherited                   True                     True
# 7            not inherited                   True                     True
# 8            not inherited                   True                     True
# 36           not inherited                   True                     True
# 37           not inherited                   True                     True
# 107          not inherited                   True                     True
# 129          not inherited                   True                     True
# 167          not inherited                   True                     True
# 197          not inherited                   True                     True
# 690                 father                   True                     True
# 1421         not inherited                   True                     True
# 2263         not inherited                   True                     True
#
# [14 rows x 22 columns]

# %% [markdown]
# ## Number of times each person appears in the database in descending order

# %%
df.groupby('name').size().sort_values(ascending = False)
# Out:
# name
# Takemitsu Takizaki     3
# Shoji Uehara           3
# James Jannard          3
# Henry Sy               3
# James Goodnight        3
#                       ..
# Michael Moritz         1
# Michael Pieper         1
# Michael Platt          1
# Michael Price          1
# A Jerrold Perenchio    1
# Length: 2077, dtype: int64

# %%
# equivalente a
df['name'].value_counts(ascending = False)
# Out:
# Warren Buffett                   3
# Gustavo Cisneros                 3
# Eliodoro Matte                   3
# Richard DeVos                    3
# Ananda Krishnan                  3
#                                 ..
# Peter Lim                        1
# Scott McNealy                    1
# Dulce Pugliese de Godoy Bueno    1
# Roger Penske                     1
# Boonsong Asavabhokhin            1
# Name: name, Length: 2077, dtype: int64

# %% [markdown]
# ## Top ten sectors (by frequency appereance in the dataset)

# %%
df.groupby('company.sector').size().sort_values(ascending = False)[0:10]
# Out:
# company.sector
# real estate        177
# retail             120
# media              117
# construction        96
# banking             93
# pharmaceuticals     76
# oil                 74
# software            67
# hedge funds         50
# technology          36
# dtype: int64

# %% [markdown]
# ## SQL IO
#
# Create a database called 'billionaries' using sqlite and save the data from the dataframe using the appropiate tables. Save the information of people, companies and the relationship between people and companies (ie. company.relationship). Use the functions viewed in class.

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite:///billionaries.db', echo = True)

from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey

# %% [markdown]
# Extract necessary information:

# %%
df.head()
# Out:
#              name  rank  year  company.founded        company.name  \
# 0      Bill Gates     1  1996             1975           Microsoft
# 1      Bill Gates     1  2001             1975           Microsoft
# 2      Bill Gates     1  2014             1975           Microsoft
# 3  Warren Buffett     2  1996             1962  Berkshire Hathaway
# 4  Warren Buffett     2  2001             1962  Berkshire Hathaway
#
#   company.relationship company.sector company.type  demographics.age  \
# 0              founder       Software          new                40
# 1              founder       Software          new                45
# 2              founder       Software          new                58
# 3              founder        Finance          new                65
# 4              founder        Finance          new                70
#
#   demographics.gender  ...    location.gdp location.region  \
# 0                male  ...   8100000000000   North America
# 1                male  ...  10600000000000   North America
# 2                male  ...               0   North America
# 3                male  ...   8100000000000   North America
# 4                male  ...  10600000000000   North America
#
#            wealth.type wealth.worth in billions wealth.how.category  \
# 0  founder non-finance                     18.5         New Sectors
# 1  founder non-finance                     58.7         New Sectors
# 2  founder non-finance                     76.0         New Sectors
# 3  founder non-finance                     15.0      Traded Sectors
# 4  founder non-finance                     32.3      Traded Sectors
#
#    wealth.how.from emerging  wealth.how.industry  wealth.how.inherited  \
# 0                      True  Technology-Computer         not inherited
# 1                      True  Technology-Computer         not inherited
# 2                      True  Technology-Computer         not inherited
# 3                      True             Consumer         not inherited
# 4                      True             Consumer         not inherited
#
#   wealth.how.was founder wealth.how.was political
# 0                   True                     True
# 1                   True                     True
# 2                   True                     True
# 3                   True                     True
# 4                   True                     True
#
# [5 rows x 22 columns]

# %%
# Tabla de personas
df_people = df[['name','location.region','year','demographics.age']]

# Introduzco el año de nacimiento para disminuir la posibilidad de 
# eliminar omonimos que no son la misma persona
df_people['born'] = df['year'] - df['demographics.age']
df_people = df_people.drop(columns = ['year','demographics.age'])

# Ahora borro los duplicados
df_people.drop_duplicates(keep = 'first', inplace = True)

df_people = df_people.reset_index()
people_columns_name = ["people_number","person_name","region","born"] 
df_people.columns = people_columns_name

df_people['id_people'] = df_people.index
#df_people = df_people[0:10]
#df_people
# Out:
# /home/nicolo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Tabla de empresas
df_company = df[['company.founded','company.name','company.sector', 'company.type','company.relationship']]

df_company.drop_duplicates(keep = 'first', inplace = True)

df_company= df_company.reset_index()

company_columns_name = ["id_people","founded","company_name","sector","type","company_relationship"] 
df_company.columns = company_columns_name

df_company['id_company'] = df_company.index
#df_company = df_company[0:10]
#df_company
# Out:
# /home/nicolo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Construyo la tabla de relaciones entre personas y empresas 
# a través de un merge de las dos tablas anteriores

df_relationship = pd.merge(df_people, df_company, left_on='people_number', right_on='id_people')
#df_relationship

# %%
# Ahora 'limpio' las tablas para que tengan solo las informaciones necesarias
people_columns = ['people_number','person_name', 'region', 'born']
df_people = df_people[people_columns]
df_people.columns = ['id_people','person_name', 'region', 'born']
#print(df_people)

company_columns = ['id_people','founded', 'company_name', 'sector', 'type', 'id_company']
df_company = df_company[company_columns]
#print(df_company)

relationship_columns = ['people_number','id_company','company_relationship']
df_relationship = df_relationship[relationship_columns]
df_relationship.columns = ['id_people','id_company','company_relationship']
#print(df_relationship)

# %%
# Paso los data_frames a tablas de SQL
df_people.to_sql('people', con = engine, if_exists = 'replace', index = False)
df_company.to_sql('company', con = engine, if_exists = 'replace', index = False)
df_relationship.to_sql('relationship', con = engine, if_exists = 'replace', index = False)
# Out:
# 2019-12-22 21:23:15,309 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-12-22 21:23:15,311 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,313 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-12-22 21:23:15,314 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,316 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("people")
# 2019-12-22 21:23:15,316 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,320 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("people")
# 2019-12-22 21:23:15,321 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,323 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2019-12-22 21:23:15,324 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,327 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("people")
# 2019-12-22 21:23:15,328 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,330 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'people' AND type = 'table'
# 2019-12-22 21:23:15,333 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,335 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("people")
# 2019-12-22 21:23:15,336 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,337 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("people")
# 2019-12-22 21:23:15,338 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,339 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'people' AND type = 'table'
# 2019-12-22 21:23:15,339 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,341 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("people")
# 2019-12-22 21:23:15,342 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,344 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("people")
# 2019-12-22 21:23:15,345 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,346 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("people")
# 2019-12-22 21:23:15,347 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,349 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("people")
# 2019-12-22 21:23:15,349 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,351 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'people' AND type = 'table'
# 2019-12-22 21:23:15,351 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,353 INFO sqlalchemy.engine.base.Engine
# DROP TABLE people
# 2019-12-22 21:23:15,354 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,374 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-12-22 21:23:15,379 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE people (
# 	id_people BIGINT,
# 	person_name TEXT,
# 	region TEXT,
# 	born BIGINT
# )
#
#
# 2019-12-22 21:23:15,380 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,398 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-12-22 21:23:15,401 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-12-22 21:23:15,432 INFO sqlalchemy.engine.base.Engine INSERT INTO people (id_people, person_name, region, born) VALUES (?, ?, ?, ?)
# 2019-12-22 21:23:15,433 INFO sqlalchemy.engine.base.Engine ((0, 'Bill Gates', 'North America', 1956), (3, 'Warren Buffett', 'North America', 1931), (5, 'Carlos Slim Helu', 'Latin America', 1940), (6, 'Oeri Hoffman and Sacher', 'Europe', 1996), (7, 'Paul Allen', 'North America', 1953), (8, 'Amancio Ortega', 'Europe', 1937), (9, 'Lee Shau Kee', 'East Asia', 1928), (10, 'Larry Ellison', 'North America', 1945)  ... displaying 10 of 2216 total bound parameter sets ...  (2612, 'Zdenek Bakala', 'Europe', 1961), (2613, 'Zhu Wenchen', 'East Asia', 1966))
# 2019-12-22 21:23:15,442 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-12-22 21:23:15,468 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("company")
# 2019-12-22 21:23:15,469 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,472 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("company")
# 2019-12-22 21:23:15,474 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,477 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2019-12-22 21:23:15,478 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,485 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("company")
# 2019-12-22 21:23:15,486 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,488 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'company' AND type = 'table'
# 2019-12-22 21:23:15,489 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,491 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("company")
# 2019-12-22 21:23:15,491 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,493 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("company")
# 2019-12-22 21:23:15,494 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,495 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'company' AND type = 'table'
# 2019-12-22 21:23:15,495 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,497 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("company")
# 2019-12-22 21:23:15,497 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,499 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("company")
# 2019-12-22 21:23:15,500 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,503 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("company")
# 2019-12-22 21:23:15,504 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,506 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("company")
# 2019-12-22 21:23:15,507 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,509 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'company' AND type = 'table'
# 2019-12-22 21:23:15,510 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,513 INFO sqlalchemy.engine.base.Engine
# DROP TABLE company
# 2019-12-22 21:23:15,514 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,538 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-12-22 21:23:15,543 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE company (
# 	id_people BIGINT,
# 	founded BIGINT,
# 	company_name TEXT,
# 	sector TEXT,
# 	type TEXT,
# 	id_company BIGINT
# )
#
#
# 2019-12-22 21:23:15,544 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,566 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-12-22 21:23:15,570 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-12-22 21:23:15,601 INFO sqlalchemy.engine.base.Engine INSERT INTO company (id_people, founded, company_name, sector, type, id_company) VALUES (?, ?, ?, ?, ?, ?)
# 2019-12-22 21:23:15,602 INFO sqlalchemy.engine.base.Engine ((0, 1975, 'Microsoft', ' Software', 'new', 0), (3, 1962, 'Berkshire Hathaway', ' Finance', 'new', 1), (5, 1990, 'Telmex', ' Communications', 'privatization', 2), (6, 1896, 'F. Hoffmann-La Roche', 'pharmaceuticals', 'new', 3), (7, 1975, 'Microsoft', 'technology', 'new', 4), (8, 1975, 'Zara', 'Fashion', 'new', 5), (9, 1976, 'Henderson Land Development', 'real estate', 'new', 6), (10, 1977, 'Oracle', ' software', ' new', 7)  ... displaying 10 of 1723 total bound parameter sets ...  (2612, 1994, 'Patria Finance', 'coal', 'new', 1721), (2613, 1999, 'Furen Pharmaceutical Group', 'pharmaceuticals', 'new', 1722))
# 2019-12-22 21:23:15,610 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-12-22 21:23:15,634 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("relationship")
# 2019-12-22 21:23:15,635 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,637 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("relationship")
# 2019-12-22 21:23:15,638 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,641 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2019-12-22 21:23:15,642 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,646 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("relationship")
# 2019-12-22 21:23:15,647 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,650 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'relationship' AND type = 'table'
# 2019-12-22 21:23:15,655 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,657 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("relationship")
# 2019-12-22 21:23:15,658 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,659 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("relationship")
# 2019-12-22 21:23:15,660 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,661 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'relationship' AND type = 'table'
# 2019-12-22 21:23:15,662 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,665 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("relationship")
# 2019-12-22 21:23:15,666 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,669 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("relationship")
# 2019-12-22 21:23:15,673 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,675 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("relationship")
# 2019-12-22 21:23:15,676 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,679 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("relationship")
# 2019-12-22 21:23:15,681 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,683 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'relationship' AND type = 'table'
# 2019-12-22 21:23:15,685 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,688 INFO sqlalchemy.engine.base.Engine
# DROP TABLE relationship
# 2019-12-22 21:23:15,690 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,707 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-12-22 21:23:15,710 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE relationship (
# 	id_people BIGINT,
# 	id_company BIGINT,
# 	company_relationship TEXT
# )
#
#
# 2019-12-22 21:23:15,711 INFO sqlalchemy.engine.base.Engine ()
# 2019-12-22 21:23:15,728 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-12-22 21:23:15,731 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-12-22 21:23:15,744 INFO sqlalchemy.engine.base.Engine INSERT INTO relationship (id_people, id_company, company_relationship) VALUES (?, ?, ?)
# 2019-12-22 21:23:15,745 INFO sqlalchemy.engine.base.Engine ((0, 0, 'founder'), (3, 1, 'founder'), (5, 2, 'founder'), (6, 3, None), (7, 4, 'founder'), (8, 5, 'founder'), (9, 6, 'founder/chairman'), (10, 7, 'founder')  ... displaying 10 of 1713 total bound parameter sets ...  (2612, 1721, 'founder'), (2613, 1722, 'chairman'))
# 2019-12-22 21:23:15,750 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# Reference I used to add primary key:
#
# https://stackoverflow.com/questions/39407254/how-to-set-the-primary-key-when-writing-a-pandas-dataframe-to-a-sqlite-database?rq=1
#
# The idea is to:
#
# "create a new table with the same column names and types while
#     defining a primary key for the desired column"

# %%
import sqlite3

# Modifico las tablas para definir primary key, foreign keys, etc.
conn = sqlite3.connect('billionaries.db')
c = conn.cursor()
    
c.executescript('''
    
    
    /* Table people */
    BEGIN TRANSACTION;
    ALTER TABLE people RENAME TO old_table;

    CREATE TABLE people (id_people int not null primary key,
                        person_name char not null,
                        region char,
                        born char); 
    
    INSERT INTO people SELECT * FROM old_table;

    DROP TABLE old_table;
    COMMIT TRANSACTION;
    
    
    /* Table company */
    BEGIN TRANSACTION;
    ALTER TABLE company RENAME TO old_table;

    CREATE TABLE company (id_people,
                         founded, 
                         company_name, 
                         sector, 
                         type, 
                         id_company); 
    
    INSERT INTO people SELECT * FROM old_table;

    DROP TABLE old_table;
    COMMIT TRANSACTION;

''')
    
#close out the connection
c.close()
conn.close()

# %%
# Miro el contenido de la tabla people
engine.execute("SELECT * FROM people").fetchall()
# Out:
# 2019-12-22 21:23:16,352 INFO sqlalchemy.engine.base.Engine SELECT * FROM people
# 2019-12-22 21:23:16,354 INFO sqlalchemy.engine.base.Engine ()
# [(0, 'Bill Gates', 'North America', 1956),
#  (3, 'Warren Buffett', 'North America', 1931),
#  (5, 'Carlos Slim Helu', 'Latin America', 1940),
#  (6, 'Oeri Hoffman and Sacher', 'Europe', 1996),
#  (7, 'Paul Allen', 'North America', 1953),
#  (8, 'Amancio Ortega', 'Europe', 1937),
#  (9, 'Lee Shau Kee', 'East Asia', 1928),
#  (10, 'Larry Ellison', 'North America', 1945),
#  (12, 'Tsai Wan-lin', 'East Asia', 1925),
#  (13, 'Theo and Karl Albrecht', 'Europe', 2001),
#  (15, 'Walter Thomas and Raymond Kwok', 'East Asia', 1996),
#  (16, 'Prince Alwaleed Bin Talal Alsaud', 'Middle East/North Africa', 1957),
#  (17, 'Charles Koch', 'North America', 1936),
#  (18, 'David Koch', 'North America', 1941),
#  (19, 'Li Ka-shing', 'East Asia', 1929),
#  (20, 'Jim Walton', 'North America', 1948),
#  (21, 'Yoshiaki Tsutsumi', 'East Asia', 1935),
#  (22, 'John Walton', 'North America', 1946),
#  (23, 'Sheldon Adelson', 'North America', 1934),
#  (24, 'Theo and Karl Albrecht', 'Europe', 1996),
#  (25, 'S Robson Walton', 'North America', 1944),
#  (26, 'Christy Walton', 'North America', 1955),
#  (27, 'Hans and Gad Rausing', 'Europe', 1996),
#  (28, 'Alice Walton', 'North America', 1949),
#  (29, 'Helen Walton', 'North America', 1920),
#  (31, 'Johanna Quandt', 'Europe', 1928),
#  (32, 'Liliane Bettencourt', 'Europe', 1923),
#  (33, 'Haniel family', 'Europe', 1996),
#  (35, 'Stefan Persson', 'Europe', 1948),
#  (37, 'Steven Ballmer', 'North America', 1957),
#  (38, 'Alice Walton', 'North America', 1950),
#  (39, 'Kenneth Thomson', 'North America', 1924),
#  (41, 'S. Robson Walton', 'North America', 1944),
#  (42, 'John Kluge', 'North America', 1915),
#  (44, 'Bernard Arnault', 'Europe', 1950),
#  (45, 'Tan Yu', 'East Asia', 1996),
#  (46, 'Philip Anschutz', 'North America', 1940),
#  (47, 'Michael Bloomberg', 'North America', 1942),
#  (48, 'Wonowidjojo family', 'East Asia', 1996),
#  (49, 'Ingvar Kamprad', 'Europe', 1927),
#  (50, 'Larry Page', 'North America', 1974),
#  (53, 'Sumner Redstone', 'North America', 1924),
#  (54, 'Jeff Bezos', 'North America', 1964),
#  (56, 'Sergey Brin', 'North America', 1974),
#  (57, 'Chung Ju-yung', 'East Asia', 1996),
#  (58, 'Leo Kirch', 'Europe', 2001),
#  (60, 'Gerard Mulliez', 'Europe', 1996),
#  (61, 'Anne Cox Chambers', 'North America', 1920),
#  (62, 'Barbara Cox Anthony', 'North America', 1924),
#  (63, 'Mark Zuckerberg', 'North America', 1985),
#  (64, 'Robert Kuok', 'East Asia', 1923),
#  (65, 'Michele Ferrero', 'Europe', 1926),
#  (66, 'Kwek Leng Beng', 'East Asia', 1941),
#  (67, 'Walter Thomas and Raymond Kwok', 'East Asia', 2001),
#  (68, 'Aliko Dangote', 'Sub-Saharan Africa', 1958),
#  (69, 'Karl Albrecht', 'Europe', 1920),
#  (70, 'Cheng Yu-tung', 'East Asia', 1926),
#  (72, 'Walter Haefner', 'Europe', 1911),
#  (74, 'Carl Icahn', 'North America', 1936),
#  (75, 'Philip Knight', 'North America', 1938),
#  (76, 'Bernard Arnault', 'Europe', 1949),
#  (77, 'George Soros', 'North America', 1931),
#  (78, 'Michael Otto', 'Europe', 1944),
#  (79, 'Ernesto Bertarelli', 'Europe', 1966),
#  (80, 'Michael Dell', 'North America', 1965),
#  (81, 'David Thomson', 'North America', 1958),
#  (82, 'Fong Teng', 'East Asia', 1996),
#  (83, 'Lui Che Woo', 'East Asia', 1930),
#  (84, 'Robert and Ten Fong Ng', 'East Asia', 1996),
#  (85, 'Silvio Berlusconi', 'Europe', 1937),
#  (86, 'Dieter Schwarz', 'Europe', 1940),
#  (87, 'Yasuo Takei', 'East Asia', 1930),
#  (88, 'Abigail Johnson', 'North America', 1962),
#  (89, 'Prince Alwaleed Bin Talal Alsaud', 'Middle East/North Africa', 1956),
#  (90, 'Antonio Ermirio de Moraes', 'Latin America', 1996),
#  (91, 'Forrest Mars Jr', 'North America', 1932),
#  (92, 'Jacqueline Mars', 'North America', 2001),
#  (93, 'John Mars', 'North America', 1937),
#  (94, 'Kirsten Rausing', 'Europe', 2001),
#  (95, 'Forrest Mars, Jr.', 'North America', 1932),
#  (96, 'Jacqueline Mars', 'North America', 1940),
#  (98, 'Eka Tjipta Widjaja', 'East Asia', 1996),
#  (100, 'Merck family', 'Europe', 1996),
#  (101, 'Jorge Paulo Lemann', 'Latin America', 1940),
#  (103, 'Charles Ergen', 'North America', 1953),
#  (104, 'Ted Turner', 'North America', 1939),
#  (106, 'Mohamed Salim Bin Mahfouz', 'Middle East/North Africa', 1996),
#  (107, 'Steve Ballmer', 'North America', 1957),
#  (108, 'Theo Albrecht, Jr.', 'Europe', 1951),
#  (109, 'Lee Kun-Hee', 'East Asia', 1996),
#  (112, 'Suliman Olayan', 'Middle East/North Africa', 2001),
#  (113, 'Leonardo Del Vecchio', 'Europe', 1936),
#  (115, 'Rupert Murdoch', 'North America', 1931),
#  (116, 'Len Blavatnik', 'North America', 1958),
#  (118, 'Hans Rausing', 'Europe', 1927),
#  (119, 'Nobutada Saji', 'East Asia', 1946),
#  (120, 'Alisher Usmanov', 'Europe', 1954),
#  (121, 'Mukesh Ambani', 'South Asia', 1958),
#  (124, 'Azim Premji', 'South Asia', 1946),
#  (125, 'Masayoshi Son', 'East Asia', 1958),
#  (127, 'Phil Knight', 'North America', 1938),
#  (128, 'Henkel family', 'Europe', 1996),
#  (129, 'Amancio Ortega', 'Europe', 1936),
#  (132, 'Friedrich Flick', 'Europe', 1927),
#  (133, 'Gerald Cavendish Grosvenor', 'Europe', 1952),
#  (134, 'Tadashi Yanai', 'East Asia', 1949),
#  (135, 'Liem Sioe Liong', 'East Asia', 1996),
#  (136, 'Kirk Kerkorian', 'North America', 1918),
#  (137, 'Gina Rinehart', 'North America', 1954),
#  (138, 'Pierre Landolt', 'Europe', 1996),
#  (139, 'Charles Schwab', 'North America', 1938),
#  (140, 'Francois Pinault', 'Europe', 1937),
#  (141, 'Mikhail Fridman', 'Europe', 1965),
#  (142, 'Donald Newhouse', 'North America', 1930),
#  (144, 'Samuel Newhouse', 'North America', 1928),
#  (145, 'Pierre Landolt', 'Europe', 2001),
#  (146, 'Susanne Klatten', 'Europe', 1963),
#  (147, 'Dhanin Chearavanont', 'East Asia', 1940),
#  (149, 'Nasser Al-Kharafi', 'Middle East/North Africa', 1944),
#  (151, 'Boehringer family', 'Europe', 1996),
#  (152, 'Viktor Vekselberg', 'Europe', 1958),
#  (153, 'David Sainsbury', 'Europe', 1941),
#  (155, 'Lakshmi Mittal', 'South Asia', 1951),
#  (156, 'Seydoux/Schlumberger families', 'Europe', 1996),
#  (157, 'Eli Broad', 'North America', 1934),
#  (158, 'Vladimir Lisin', 'Europe', 1957),
#  (159, 'Masatoshi Ito', 'East Asia', 1925),
#  (160, 'James Goodnight', 'North America', 1943),
#  (162, 'Fukuzo Iwasaki', 'East Asia', 1925),
#  (163, 'Kyosuke Kinoshita', 'East Asia', 1941),
#  (165, 'Joseph Safra', 'Latin America', 1939),
#  (166, 'Mustafa Rahmi Koc', 'Middle East/North Africa', 1931),
#  (169, 'Luciano Benetton', 'Europe', 1936),
#  (170, 'Robert Pritzker', 'North America', 1927),
#  (171, 'Thomas Pritzker', 'North America', 1951),
#  (172, 'Leonid Mikhelson', 'Europe', 1956),
#  (176, 'Iris Fontbona', 'Latin America', 1943),
#  (177, 'Ronald Perelman', 'North America', 1943),
#  (178, 'Akira Mori', 'East Asia', 1930),
#  (179, 'Curt Engelhorn', 'Europe', 1927),
#  (180, 'Gordon Moore', 'North America', 1929),
#  (181, 'Hasso Plattner', 'Europe', 1944),
#  (182, 'Paul-Louis Halley', 'Europe', 2001),
#  (183, 'Otto Beisheim', 'Europe', 1924),
#  (185, 'Gennady Timchenko', 'Europe', 1953),
#  (186, 'Mohammad Al Amoudi', 'Middle East/North Africa', 1947),
#  (187, 'Madeleine Schickedanz', 'Europe', 1944),
#  (188, 'Brenninkmeijer family', 'Europe', 1996),
#  (191, 'Gustavo Cisneros', 'Latin America', 1946),
#  (194, 'Wang Jianlin', 'East Asia', 1955),
#  (195, 'Walter Annenberg', 'North America', 1996),
#  (198, 'Stefan Quandt', 'Europe', 1967),
#  (199, 'Gregorio Perez Companc', 'Latin America', 1935),
#  (200, 'German Larrea Mota Velasco', 'Latin America', 1954),
#  (202, 'Yoshitaka Fukuda', 'East Asia', 1948),
#  (203, 'Harold Hamm', 'North America', 1946),
#  (204, 'Shin Kyuk-Ho', 'East Asia', 1996),
#  (205, 'Alfred Lerner', 'North America', 2001),
#  (206, 'Donald Bren', 'North America', 1933),
#  (207, 'Ray Dalio', 'North America', 1950),
#  (208, 'James Arthur and John Irving', 'North America', 1996),
#  (209, 'Alain Wertheimer', 'Europe', 2001),
#  (210, 'August von Finck', 'Europe', 1931),
#  (214, 'Philip Niarchos', 'Europe', 1954),
#  (215, 'Georg Schaeffler', 'Europe', 1965),
#  (216, 'Wang Yue-che', 'East Asia', 1917),
#  (217, 'Luis Carlos Sarmiento', 'Latin America', 1933),
#  (218, 'Sakip Sabanci', 'Middle East/North Africa', 1933),
#  (219, 'Laurene Powell Jobs', 'North America', 1964),
#  (221, 'Serge Dassault', 'Europe', 1926),
#  (222, 'Erivan Haub', 'Europe', 1933),
#  (223, 'Tiong Hiew King', 'East Asia', 1936),
#  (224, 'Serge Dassault', 'Europe', 1925),
#  (226, 'Gunter Herz', 'Europe', 1941),
#  (228, 'John Fredriksen', 'Europe', 1945),
#  (229, 'Vagit Alekperov', 'Europe', 1951),
#  (231, 'Denis Defforey', 'Europe', 1996),
#  (232, 'Rolf Gerling', 'Europe', 1955),
#  (233, 'John Paulson', 'North America', 1956),
#  (234, 'Rupert Murdoch', 'North America', 1932),
#  (236, 'Dieter von Holtzbrinck', 'Europe', 1942),
#  (237, 'Edward Johnson', 'North America', 1931),
#  (238, 'Spiro Latsis', 'Europe', 1947),
#  (239, 'Nina Wang', 'East Asia', 1996),
#  (240, 'Ma Huateng', 'East Asia', 1972),
#  (241, 'Quek Leng Chan', 'East Asia', 1941),
#  (243, 'Garry Weston', 'Europe', 1996),
#  (244, 'Lorenzo Mendoza', 'Latin America', 1966),
#  (245, 'Marvin Davis', 'North America', 1926),
#  (247, 'Michael Bloomberg', 'North America', 1943),
#  (248, 'Nicky Oppenheimer', 'Sub-Saharan Africa', 1946),
#  (249, 'Pierre Omidyar', 'North America', 1968),
#  (250, 'Reinhard Mohn', 'Europe', 1922),
#  (251, 'Samuel Johnson', 'North America', 1929),
#  (252, 'Dilip Shanghvi', 'South Asia', 1956),
#  (253, 'Jack Taylor', 'North America', 1923),
#  (254, 'Johanna Quandt', 'Europe', 1927),
#  (255, 'Pallonji Mistry', 'Europe', 1930),
#  (256, 'Henry Ross Perot Sr', 'North America', 1996),
#  (257, 'Keizo Saji', 'East Asia', 1996),
#  (259, 'Richard DeVos', 'North America', 1926),
#  (260, 'Thomas and Raymond Kwok', 'East Asia', 2014),
#  (261, 'Vladimir Potanin', 'Europe', 1961),
#  (262, 'Jay Van Andel', 'North America', 1925),
#  (264, 'James Simons', 'North America', 1939),
#  (265, 'Rinat Akhmetov', 'Europe', 1967),
#  (266, 'Michael and Rainer Schmidt-Ruthenbeck', 'Europe', 1996),
#  (267, 'Stanley Ho', 'East Asia', 1922),
#  (268, 'James Arthur and John Irving', 'North America', 2001),
#  (269, 'Rudolf Oetker', 'Europe', 2001),
#  (270, 'Alberto Bailleres Gonzalez', 'Latin America', 1932),
#  (272, 'Robin Li', 'East Asia', 1969),
#  (273, 'Chatri Sophonpanich', 'East Asia', 1996),
#  (274, 'Lee Bass', 'North America', 1957),
#  (275, 'Maurice Greenberg', 'North America', 1926),
#  (279, 'Peter Haas Sr', 'North America', 1996),
#  (280, 'Lemos family', 'Europe', 1996),
#  (281, 'Zong Qinghou', 'East Asia', 1946),
#  (282, 'Jassim Al-Kharafi', 'Middle East/North Africa', 1996),
#  (284, 'David & Simon Reuben', 'Europe', 1943),
#  (285, 'Robert Kuok', 'East Asia', 1924),
#  (286, 'Suliman Olayan', 'Middle East/North Africa', 1996),
#  (287, 'Micky Arison', 'North America', 1950),
#  (288, 'Patrick Wang', 'East Asia', 1951),
#  (289, 'Khoo Teck Puat', 'East Asia', 1917),
#  (290, 'Andrey Melnichenko', 'Europe', 1973),
#  (292, 'Henry Sy', 'East Asia', 1925),
#  (294, 'Alfred Heineken', 'Europe', 2001),
#  (297, 'Galen Weston', 'North America', 1941),
#  (298, 'Ty Warner', 'North America', 1944),
#  (299, 'Walter Annenberg', 'North America', 2001),
#  (300, 'Jacqueline Mars', 'North America', 1996),
#  (301, 'Jay and Arthur Pritzker', 'North America', 1996),
#  (302, 'Ananda Krishnan', 'East Asia', 1939),
#  (303, 'German Khan', 'Europe', 1962),
#  (305, 'Forrest Mars Sr', 'North America', 1996),
#  (306, 'Alejandro Santo Domingo Davila', 'Latin America', 1977),
#  (307, 'Lee Kun-Hee', 'East Asia', 1942),
#  (308, 'Miuccia Prada', 'Europe', 1950),
#  (309, 'Shiv Nadar', 'South Asia', 1946),
#  (311, 'Rudolf Oetker', 'Europe', 1996),
#  (312, 'Henry Ross Perot Sr', 'North America', 2001),
#  (313, 'Jon Huntsman', 'North America', 1938),
#  (314, 'Leonard Lauder', 'North America', 1934),
#  (315, 'Sid Bass', 'North America', 1943),
#  (317, 'Koo Cha-kyung', 'East Asia', 1996),
#  (318, 'William Hewlett', 'North America', 1996),
#  (319, 'Petr Kellner', 'Europe', 1965),
#  (320, 'Robert & Philip Ng', 'East Asia', 2014),
#  (321, 'Steve Cohen', 'North America', 1956),
#  (322, 'Karl-Heinz Kipp', 'Europe', 1924),
#  (323, 'Putera Sampoerna', 'East Asia', 1996),
#  (324, 'Gianni Agnelli', 'Europe', 1996),
#  (326, 'Mehmet Karamehmet', 'Middle East/North Africa', 1945),
#  (327, 'Nina Wang', 'East Asia', 2001),
#  (329, 'Sanjiv Sidhu', 'North America', 2001),
#  (330, 'Shari Arison', 'Middle East/North Africa', 1958),
#  (331, 'Andrew Beal', 'North America', 1953),
#  (332, 'Mikhail Prokhorov', 'Europe', 1966),
#  (333, 'Chey Jong-hyon', 'East Asia', 1996),
#  (334, 'Jean-Louis Dumas', 'Europe', 1939),
#  (335, 'Alexei Mordashov', 'Europe', 1966),
#  (336, 'Hansjoerg Wyss', 'Europe', 1935),
#  (337, 'Dietmar Hopp', 'Europe', 1941),
#  (339, 'Charlene de Carvalho-Heineken', 'Europe', 1955),
#  (340, 'Klaus-Michael Kuehne', 'Europe', 1938),
#  (342, 'Stefano Pessina', 'Europe', 1942),
#  (343, 'Lim Goh Tong', 'East Asia', 1918),
#  (344, 'Eugene Wu', 'East Asia', 1996),
#  (345, 'John Simplot', 'North America', 1909),
#  (346, 'Edgar Bronfman', 'North America', 1929),
#  (347, 'Antonio Ermirio de Moraes', 'Latin America', 2001),
#  (348, 'Craig McCaw', 'North America', 1950),
#  (349, 'Kazuo Okada', 'East Asia', 1943),
#  (350, 'Ng Teng Fong', 'East Asia', 1929),
#  (351, 'Nicolas Hayek', 'Europe', 1929),
#  (352, 'Reinhold Wuerth', 'Europe', 2001),
#  (354, 'Stephan Schmidheiny', 'Europe', 1948),
#  (355, 'Charles Bronfman', 'North America', 1932),
#  (356, 'Li Hejun', 'East Asia', 1968),
#  (357, 'Sergei Galitsky', 'Europe', 1968),
#  (358, 'Leo Kirch', 'Europe', 1996),
#  (359, 'Von Siemens family', 'Europe', 1996),
#  (360, 'Kjeld Kirk Kristiansen', 'Europe', 1948),
#  (361, 'Marcel Herrmann Telles', 'Latin America', 1950),
#  (362, 'John Latsis', 'Europe', 1996),
#  (363, 'Yaw Teck-seng', 'East Asia', 1996),
#  (364, 'Charles Butt', 'North America', 1938),
#  (365, 'Alfred Heineken', 'Europe', 1996),
#  (366, 'Carrie Perrodo', 'Europe', 1951),
#  (367, 'David Tepper', 'North America', 1958),
#  (368, 'George Kaiser', 'North America', 1943),
#  (369, 'Hinduja Brothers', 'Europe', 2014),
#  (370, 'Jack Ma', 'East Asia', 1965),
#  (371, 'Patrick Soon-Shiong', 'North America', 1952),
#  (372, 'Stephen Schwarzman', 'North America', 1947),
#  (373, 'Jaime Augusto Zobel de Ayala', 'East Asia', 1996),
#  (374, 'George Ty', 'East Asia', 1996),
#  (375, 'Ann Kroenke', 'North America', 2001),
#  (377, 'David Geffen', 'North America', 1943),
#  (378, 'Dhirubhai Ambani', 'South Asia', 2001),
#  (379, 'Gerard Louis-Dreyfus', 'Europe', 1933),
#  (380, 'James Sorenson', 'North America', 1922),
#  (382, 'Henry Hillman', 'North America', 1919),
#  (383, 'Julio Bozano', 'Latin America', 1936),
#  (384, 'Porsche family', 'Europe', 1996),
#  (385, 'Peter Livanos', 'Europe', 1996),
#  (386, 'Giorgio Armani', 'Europe', 1935),
#  (387, 'Michael Kadoorie', 'East Asia', 1941),
#  (388, 'Akira Mori', 'East Asia', 1935),
#  (389, 'Amos Hosetter Jr', 'North America', 1937),
#  (390, 'Bernard Marcus', 'North America', 1930),
#  (392, 'Eitaro Itoyama', 'East Asia', 1943),
#  (393, 'Martin Ebner', 'Europe', 2001),
#  (395, 'Ryoichi Jinnai', 'East Asia', 1927),
#  (396, 'Richard Kinder', 'North America', 1945),
#  (397, 'Tsai Eng-Meng', 'East Asia', 1957),
#  (398, 'Henry Fok', 'East Asia', 1924),
#  (399, 'Goroemon Yoshimoto', 'East Asia', 1996),
#  (400, 'Edward Johnson, III.', 'North America', 1931),
#  (401, 'Eric Schmidt', 'North America', 1956),
#  (402, 'Hiroshi Mikitani', 'East Asia', 1965),
#  (403, 'Samuel Newhouse, Jr.', 'North America', 1928),
#  (404, 'Rinji Shino', 'East Asia', 1996),
#  (405, 'Yasuyuki Nambu', 'East Asia', 1996),
#  (406, 'Rafik Al-Hariri', 'Middle East/North Africa', 1944),
#  (407, 'Alejo Peralta', 'Latin America', 1996),
#  (408, 'Dietrich Mateschitz', 'Europe', 1945),
#  (409, 'John van Vlissingen', 'Europe', 1939),
#  (410, 'Joao Roberto Marinho', 'Latin America', 1954),
#  (411, 'Jose Roberto Marinho', 'Latin America', 1956),
#  (412, 'Roberto Marinho', 'Latin America', 1948),
#  (413, 'Roman Abramovich', 'Europe', 1967),
#  (414, 'Sheikh Saleh Bin Abdul Aziz Al-rajhi', 'Middle East/North Africa', 1996),
#  (417, 'Donald Fisher', 'North America', 1929),
#  (418, 'Doris Fisher', 'North America', 1931),
#  (420, 'Philippe Foriel-Destezet', 'Europe', 1936),
#  (421, 'Preston Tisch', 'North America', 1927),
#  (422, 'Ronald Lauder', 'North America', 1942),
#  (423, 'Mohammed Jameel', 'Middle East/North Africa', 1996),
#  (424, 'Maersk McKinney Moller', 'Europe', 1914),
#  (426, 'Alain Wertheimer', 'Europe', 1949),
#  (427, 'Charoen Sirivadhanabhakdi', 'East Asia', 1945),
#  (428, 'Gerard Wertheimer', 'Europe', 1951),
#  (430, 'Vladimir Yevtushenkov', 'Europe', 1949),
#  (432, 'Banyong Lamsam', 'East Asia', 1996),
#  (436, 'Ennio Doris', 'Europe', 1941),
#  (437, 'Gianni Agnelli', 'Europe', 2001),
#  (438, 'Lester Crown', 'North America', 1926),
#  (440, 'William Wrigley', 'North America', 1964),
#  (441, 'Carlos Alberto Sicupira', 'Latin America', 1948),
#  (442, 'Hisakazu Yamaguchi', 'East Asia', 1996),
#  (443, 'Alexei Kuzmichev', 'Europe', 1963),
#  (444, 'Dmitry Rybolovlev', 'Europe', 1967),
#  (445, 'Elaine Marshall', 'North America', 1943),
#  (447, 'Thomas Peterffy', 'North America', 1945),
#  (448, 'Kanichiro Ishibashi', 'East Asia', 1996),
#  (449, 'Andrew Gotianun', 'East Asia', 1996),
#  (450, 'Anacleto Angelini', 'Latin America', 1914),
#  (451, 'Dieter Schwarz', 'Europe', 1996),
#  (452, 'A Jerrold Perenchio', 'North America', 1931),
#  (453, 'Emilio Azcarraga Jean', 'Latin America', 1968),
#  (454, 'George Lucas', 'North America', 1945),
#  (457, 'Mohammed Jameel', 'Middle East/North Africa', 2001),
#  (458, 'Ricardo Salinas Pliego', 'Latin America', 1956),
#  (459, 'Riley Bechtel', 'North America', 1953),
#  (460, 'Robert Bass', 'North America', 1948),
#  (461, 'Saleh Kamel', 'Middle East/North Africa', 1942),
#  (462, 'Stephen Bechtel', 'North America', 1926),
#  (463, 'Ciputra', 'East Asia', 1996),
#  (464, 'Ludwig Merckle', 'Europe', 1965),
#  (466, 'Antonia Johnson', 'Europe', 1944),
#  (469, 'Hank & Doug Meijer', 'North America', 2014),
#  (470, 'Michael Kadoorie', 'East Asia', 1942),
#  (471, 'Michele Ferrero', 'Europe', 1927),
#  (473, 'Akio Morita', 'East Asia', 1996),
#  (474, 'Kim Woo-choong', 'East Asia', 1996),
#  (476, 'Elon Musk', 'North America', 1972),
#  (477, 'Joseph Lau', 'East Asia', 1952),
#  (482, 'Andronico Luksic', 'Latin America', 1927),
#  (483, 'Adrian and John Swire', 'East Asia', 1996),
#  (485, 'Hiroshi Yamauchi', 'East Asia', 1928),
#  (486, 'Joseph and Moise Safra', 'Latin America', 2001),
#  (487, 'Leslie Wexner', 'North America', 1942),
#  (488, 'Lorenzo Zambrano', 'Latin America', 1945),
#  (489, 'Andrei Skoch', 'Europe', 1966),
#  (491, 'Xavier Niel', 'Europe', 1968),
#  (492, 'Prajogo Pangestu', 'East Asia', 1996),
#  (493, 'Akihiko Otsuka', 'East Asia', 1996),
#  (494, 'Kazuo Matsuda', 'East Asia', 1996),
#  (495, 'Margarita Louis-Dreyfus', 'Europe', 1964),
#  (496, 'Lucio Tan', 'East Asia', 1935),
#  (497, 'Pierre Castel', 'Europe', 1927),
#  (499, 'Aloysio de Andrade Faria', 'Latin America', 1921),
#  (500, 'Charles Dolan', 'North America', 1927),
#  (501, 'Jack Taylor', 'North America', 2001),
#  (502, 'John Sall', 'North America', 1947),
#  (503, 'Klaus Jacobs', 'Europe', 2001),
#  (504, 'Steven Udvar-Hazy', 'North America', 1946),
#  (506, 'Emmanuel Besnier', 'Europe', 1971),
#  (508, 'Blair Parry-Okeden', 'North America', 1951),
#  (509, 'David Duffield', 'North America', 1941),
#  (510, 'Jean-Claude Decaux', 'Europe', 1938),
#  (511, 'Jim Kennedy', 'North America', 1948),
#  (512, 'Reinhold Wuerth', 'Europe', 1936),
#  (514, 'Roberto Marinho', 'Latin America', 1996),
#  (515, 'Philippe Bouriez', 'Europe', 1996),
#  (516, 'Stefan Schoerghuber', 'Europe', 1962),
#  (517, 'Anneliese Brost', 'Europe', 1921),
#  (518, 'Jacques Servier', 'Europe', 1922),
#  (519, 'Johann Rupert', 'Sub-Saharan Africa', 1951),
#  (520, 'R Budi Hartono', 'East Asia', 1941),
#  (521, 'Tsai Wan-Tsai', 'East Asia', 1930),
#  (522, 'Funke family', 'Europe', 1996),
#  (523, 'Bruno Schroder', 'Europe', 1933),
#  (525, 'Jeffrey Skoll', 'North America', 1965),
#  (526, 'Samuel LeFrak', 'North America', 2001),
#  (528, 'Kumar Birla', 'South Asia', 1968),
#  (529, 'Masahiro Ohga', 'East Asia', 1996),
#  (531, 'Charles Johnson', 'North America', 1933),
#  (533, 'John Malone', 'North America', 1942),
#  (534, 'John Menard, Jr.', 'North America', 1940),
#  (535, 'Klaus Tschira', 'Europe', 1941),
#  (537, 'Lee Seng Wee', 'East Asia', 1925),
#  (538, 'Jeffrey Koo Sr', 'East Asia', 1996),
#  (539, 'Den Fujita', 'East Asia', 1926),
#  (541, 'Thomas Schmidheiny', 'Europe', 1946),
#  (542, 'Thaksin Shinawatra', 'East Asia', 1996),
#  (544, 'Ronald Lauder', 'North America', 1937),
#  (545, 'Alan Gerry', 'North America', 1930),
#  (546, 'Bernard Ecclestone', 'Europe', 1931),
#  (547, 'David Rockefeller', 'North America', 1916),
#  (548, 'Eugenio Garza Lagnera', 'Latin America', 2001),
#  (549, 'Joan Kroc', 'North America', 2001),
#  (550, 'John Malone', 'North America', 1941),
#  (551, 'Kerry Packer', 'North America', 1938),
#  (552, 'Michael and Rainer Schmidt-Ruthenbeck', 'Europe', 2001),
#  (555, 'Robert Rowling', 'North America', 1954),
#  (556, 'Takemitsu Takizaki', 'East Asia', 1946),
#  (558, 'Vincent Bollore', 'Europe', 1953),
#  (559, 'Michel Fribourg', 'North America', 1996),
#  (560, 'Jim Pattison', 'North America', 1929),
#  (561, 'Michael Hartono', 'East Asia', 1940),
#  (562, 'Roberto Rocca', 'Latin America', 1996),
#  (563, 'Dirce Navarro Camargo', 'Latin America', 1996),
#  (564, 'Augusto & Giorgio Perfetti', 'Europe', 2014),
#  (565, 'Heinz Hermann Thiele', 'Europe', 1942),
#  (566, 'Johann Graf', 'Europe', 1947),
#  (567, 'Peter Woo', 'East Asia', 1946),
#  (568, 'Alain Wertheimer', 'Europe', 1996),
#  (569, 'Jacques Servier', 'Europe', 1996),
#  (570, 'Verspieren family', 'Europe', 1996),
#  (571, 'Alfred von Oppenheim', 'Europe', 1996),
#  (572, 'He Xiangjian', 'East Asia', 1943),
#  (575, 'Eyal Ofer', 'Middle East/North Africa', 1951),
#  (576, 'Graeme Hart', 'North America', 1956),
#  (578, 'Ralph Lauren', 'North America', 1940),
#  (579, 'Djuhar Sutanto', 'East Asia', 1996),
#  (580, 'Theodore Arison', 'Middle East/North Africa', 1996),
#  (582, 'Henry Nicholas', 'North America', 1962),
#  (583, 'Laurence Tisch', 'North America', 2001),
#  (584, 'Leonard Stern', 'North America', 1939),
#  (585, 'Mikhail Khodorkovsky', 'Europe', 1964),
#  (587, 'John Gokongwei', 'East Asia', 1996),
#  (588, 'Charles Cadogan', 'Europe', 1938),
#  (591, 'Suleiman Kerimov', 'Europe', 1967),
#  (592, 'Wei Jianjun', 'East Asia', 1964),
#  (593, 'Yang Huiyan', 'East Asia', 1982),
#  (595, 'Manuel Villar', 'East Asia', 1996),
#  (597, 'Gordon Getty', 'North America', 1941),
#  (598, 'Henry Samueli', 'North America', 1955),
#  (599, 'Martin Bouygues', 'Europe', 1952),
#  (600, 'Ralph Lauren', 'North America', 1939),
#  (601, 'Ray Hunt', 'North America', 1943),
#  (602, 'Richard Schulze', 'North America', 1941),
#  (603, 'Robert Bosch Jr', 'Europe', 1928),
#  (604, 'Susan Thompson Buffett', 'North America', 1933),
#  (605, 'Terry Gou', 'East Asia', 2001),
#  (606, 'William Davidson', 'North America', 1923),
#  (607, 'Emilio Botin', 'Europe', 1935),
#  (611, 'Chung Mong-Koo', 'East Asia', 1939),
#  (612, 'Dustin Moskovitz', 'North America', 1985),
#  (613, 'Jan Koum', 'North America', 1976),
#  (617, 'Nassef Sawiris', 'Europe', 1961),
#  (619, 'Martha Ingram', 'North America', 1936),
#  (623, 'James Packer', 'North America', 1968),
#  (624, 'Leonid Fedun', 'Europe', 1957),
#  (626, 'Oleg Deripaska', 'Europe', 1968),
#  (627, 'Laurence Tisch', 'North America', 1996),
#  (628, 'Barbara Piasecka Johnson', 'North America', 1937),
#  (629, 'Bernard Sherman', 'North America', 1942),
#  (631, 'Frank Lowy', 'North America', 1931),
#  (632, 'H Wayne Huizenga', 'North America', 1938),
#  (633, 'James Kim', 'North America', 1936),
#  (637, 'Nancy Walton Laurie', 'North America', 1952),
#  (639, 'Tadahiro Yoshida', 'East Asia', 1947),
#  (640, 'Thomas Siebel', 'North America', 1953),
#  (642, 'Shoji Uehara', 'East Asia', 1996),
#  (643, 'Chaijudh Karnasuta', 'East Asia', 1996),
#  (644, 'Eva Gonda Rivera', 'Latin America', 2014),
#  (645, 'Pansy Ho', 'East Asia', 1963),
#  (646, 'Quek Leng Chan', 'East Asia', 1944),
#  (648, 'Mary Alice Dorrance Malone', 'North America', 1950),
#  (650, 'Dannine Avara', 'North America', 1964),
#  (651, 'Herbert Kohler, Jr.', 'North America', 1939),
#  (652, 'Ivan Glasenberg', 'North America', 1957),
#  (653, 'Milane Frantz', 'North America', 1970),
#  (654, 'Paolo & Gianfelice Mario Rocca', 'Europe', 2014),
#  (655, 'Patrick Drahi', 'Europe', 1964),
#  (656, 'Randa Williams', 'North America', 1962),
#  (657, 'Scott Duncan', 'North America', 1983),
#  (662, 'Hugo Mann', 'Europe', 1914),
#  (663, 'Lee Hon Chiu', 'East Asia', 1996),
#  (664, 'Lorenzo Rossi di Montelera', 'Europe', 1996),
#  (665, 'Abdullah Al Rajhi', 'Middle East/North Africa', 2001),
#  (666, 'Achille Maramotti', 'Europe', 1927),
#  (667, 'Adolf Merckle', 'Europe', 1935),
#  (668, 'Adrian Swire', 'Europe', 1931),
#  (670, 'Edmund Wattis Littlefield', 'North America', 2001),
#  (671, 'Ernest Stempel', '0', 1917),
#  (672, 'John Dorrance', 'Europe', 1944),
#  (673, 'Louis Gonda', 'North America', 1949),
#  (674, 'Sammy Ofer', 'Middle East/North Africa', 2001),
#  (675, 'Sergio Mantegazza', 'Europe', 1928),
#  (676, 'Steven Spielberg', 'North America', 1947),
#  (677, 'Edmond Safra', 'Middle East/North Africa', 1996),
#  (678, 'Teh Hong Piow', 'East Asia', 1940),
#  (679, 'Rupert Johnson, Jr.', 'North America', 1942),
#  (680, 'S. Truett Cathy', 'North America', 1922),
#  (682, 'Alberto Bailleres Gonzalez', 'Latin America', 1933),
#  (683, 'Huang Shi-hui', 'East Asia', 1996),
#  (684, 'Moores family', 'Europe', 1996),
#  (686, 'Iskander Makhmudov', 'Europe', 1964),
#  (688, 'Pyotr Aven', 'Europe', 1956),
#  (689, 'Richard LeFrak', 'North America', 1946),
#  (690, 'Sandra Ortega Mera', 'Europe', 1969),
#  (691, 'Thomas Frist, Jr.', 'North America', 1939),
#  (692, 'Bennett Dorrance', 'North America', 1933),
#  (693, 'Stanley Hubbard', 'North America', 1934),
#  (694, 'Eliodoro Matte', 'Latin America', 1946),
#  (695, 'Goulandris family', 'Europe', 1996),
#  (697, 'Masakuni Osano', 'East Asia', 1996),
#  (699, 'Antonio Champalimaud', 'Europe', 1919),
#  (700, 'Ayhan Sahenk', 'Middle East/North Africa', 2001),
#  (701, 'Edward Gaylord', 'North America', 2001),
#  (702, 'Fayez Sarofim', 'North America', 1929),
#  (703, 'Gary Winnick', 'North America', 2001),
#  (704, 'Georg Thyssen-Bornemisza', 'Europe', 2001),
#  (705, 'Hubert Burda', 'Europe', 1940),
#  (707, 'Jeffrey Bezos', 'North America', 1964),
#  (708, 'John Menard', 'North America', 1940),
#  (709, 'John Morgridge', 'North America', 1934),
#  (710, 'Patrick McGovern', 'North America', 1938),
#  (711, 'Peter Kellogg', 'North America', 1943),
#  (712, 'Richard Egan', 'North America', 1936),
#  (713, 'Richard Li', 'East Asia', 1967),
#  (714, 'Robert Naify', 'North America', 1922),
#  (715, 'Theodore Waitt', 'North America', 1963),
#  (716, 'Chan Laiwa', 'East Asia', 1941),
#  (717, "Denis O'Brien", 'Europe', 1959),
#  (718, 'Filaret Galchev', 'Europe', 1964),
#  (719, 'Ira Rennert', 'North America', 1935),
#  (720, 'James Irving', 'North America', 1929),
#  (721, 'Patrizio Bertelli', 'Europe', 1946),
#  (722, 'Piya Bhirombhakdi', 'East Asia', 1996),
#  (723, 'Boonchai Bencharongkul', 'East Asia', 1996),
#  (724, 'Gordon Getty', 'North America', 1951),
#  (726, 'Harry Brakemann Helmsley', 'North America', 1996),
#  (727, 'Joan Kroc', 'North America', 1996),
#  (729, 'Dennis Washington', 'North America', 1935),
#  (730, 'Gayle Cook', 'North America', 1934),
#  (731, 'Leon Black', 'North America', 1952),
#  (733, 'Luis Carlos Sarmiento Angulo', 'Latin America', 1933),
#  (734, 'Paul-Louis Halley', 'Europe', 1996),
#  (735, 'Rochling family', 'Europe', 1996),
#  (736, 'Hui Ka Yan', 'East Asia', 1959),
#  (737, 'Hui Wing Mau', 'East Asia', 1951),
#  (738, 'Idan Ofer', 'Middle East/North Africa', 1956),
#  (739, 'Isak Andic', 'Europe', 1954),
#  (740, 'Jorn Rausing', 'Europe', 1960),
#  (741, 'Leslie Wexner', 'North America', 1938),
#  (743, 'Sunil Mittal', 'South Asia', 1958),
#  (745, 'Lo Ying Shek', 'East Asia', 1996),
#  (747, 'Kenkichi Nakajima', 'East Asia', 1996),
#  (748, 'Kunio Busujima', 'East Asia', 2038),
#  (749, 'Anton Rupert', 'Sub-Saharan Africa', 1996),
#  (751, 'Abdul Aziz Al Ghurair', 'Middle East/North Africa', 1954),
#  (752, 'Akihiko Otsuka', 'East Asia', 2001),
#  (754, 'Arthur Blank', 'North America', 1943),
#  (755, 'Glen Taylor', 'North America', 1942),
#  (757, 'John Hargreaves', 'Europe', 1944),
#  (758, 'John Jahr', 'Europe', 2001),
#  (759, 'Khalid Bin Mahfouz', 'Middle East/North Africa', 1947),
#  (761, 'Leona Helmsley', 'North America', 1920),
#  (762, 'Lowry Mays', 'North America', 2001),
#  (763, 'Masao Morita', 'East Asia', 2001),
#  (764, 'Michael Krasny', 'North America', 1954),
#  (765, 'Paolo Bulgari', 'Europe', 2001),
#  (766, 'Richard Rainwater', 'North America', 1945),
#  (767, 'Robert Fisher', 'North America', 1954),
#  (768, 'Sam Zell', 'North America', 1942),
#  (769, 'Stefan Schoerghuber', 'Europe', 2001),
#  (770, 'Terence Matthews', 'North America', 2001),
#  (771, 'Yasuyuki Nambu', 'East Asia', 2001),
#  (773, 'Peter Nicholas', 'North America', 1941),
#  (774, 'Ray Lee Hunt', 'North America', 1943),
#  (775, 'Stanley Kroenke', 'North America', 1948),
#  (776, 'Teh Hong Piow', 'East Asia', 1931),
#  (778, 'Peugeot family', 'Europe', 1996),
#  (779, 'Karl Diehl', 'Europe', 1996),
#  (780, 'Arthur Irving', 'North America', 1930),
#  (782, 'Carlos and Alejandro Bulgheroni', 'Latin America', 2014),
#  (783, 'Jeffery Hildebrand', 'North America', 1960),
#  (784, 'Liu Yongxing', 'East Asia', 1949),
#  (785, 'Michael Ashley', 'Europe', 1965),
#  (787, 'Simon family', 'Europe', 1996),
#  (788, 'Albert von Thurn und Taxis', 'Europe', 1984),
#  (789, 'John Jahr', 'Europe', 1996),
#  (790, 'Freudenberg family', 'Europe', 1996),
#  (792, 'Kenshin Oshima', 'East Asia', 1948),
#  (793, 'Martin Hilti', 'Europe', 1996),
#  (794, 'Melker Schorling', 'Europe', 1948),
#  (795, 'Sergei Popov', 'Europe', 1972),
#  (796, 'Stephen Ross', 'North America', 1941),
#  (797, 'Terry Gou', 'East Asia', 1951),
#  (798, 'Yeoh Tiong Lay', 'East Asia', 1996),
#  (800, 'Bernardo Garza Sada', 'Latin America', 1996),
#  (801, 'Juffali family', 'Middle East/North Africa', 1996),
#  (802, 'Americo Amorim', 'Europe', 1935),
#  (803, 'Anders Holch Povlsen', 'Europe', 1973),
#  (804, 'Stef Wertheimer', 'Middle East/North Africa', 1927),
#  (805, 'Willi and Isolde Liebherr', 'Europe', 1996),
#  (806, 'Martin Ebner', 'Europe', 1996),
#  (808, 'Andrew Forrest', 'North America', 1962),
#  (809, 'Bidzina Ivanishvili', 'Europe', 1956),
#  (811, 'Ken Griffin', 'North America', 1969),
#  (812, 'Kwee brothers', 'East Asia', 1945),
#  (813, 'Maria Asuncion Aramburuzabala', 'Latin America', 1964),
#  (814, 'Wee Cho Yaw', 'East Asia', 1929),
#  (815, 'Shi Wen-long', 'East Asia', 1996),
#  (816, 'Prachai Leophairatana', 'East Asia', 1996),
#  (817, 'Blase Golisano', 'North America', 1942),
#  (818, 'Carl Pohlad', 'North America', 1916),
#  (819, 'Charles Butt', 'North America', 1939),
#  (820, 'Daniel Abraham', 'North America', 2001),
#  (821, 'Donald Hall', 'North America', 1929),
#  (822, 'Herbert Allen', 'North America', 1940),
#  (823, 'Irwin Jacobs', 'North America', 1934),
#  (824, 'Jeronimo Arango', 'Latin America', 1926),
#  (825, 'John Fisher', 'North America', 1962),
#  (826, 'Juan and Carlos March', 'Europe', 2001),
#  (828, 'Kenichi Mabuchi', 'East Asia', 1953),
#  (829, 'Lakshmi Mittal', 'Europe', 1951),
#  (830, 'Leslie Gonda', 'North America', 1920),
#  (833, 'Richard Branson', 'Europe', 1951),
#  (834, 'Richard Farmer', 'North America', 1935),
#  (835, 'Ronald Burkle', 'North America', 1953),
#  (837, 'John Abele', 'North America', 1917),
#  (838, 'James Cargill', 'North America', 1925),
#  (839, 'Margaret Cargill', 'North America', 1920),
#  (840, 'Michel David-Weill', 'Europe', 1996),
#  (843, 'Finn Rausing', 'Europe', 1955),
#  (844, 'Jacqueline Desmarais', 'North America', 1929),
#  (845, 'Kirsten Rausing', 'Europe', 1953),
#  (848, 'Tajudin Ramli', 'East Asia', 1996),
#  (849, 'Anil Ambani', 'South Asia', 1960),
#  (850, 'Antonio Del Valle Ruiz', 'Latin America', 1939),
#  (851, 'Bruce Halle', 'North America', 1931),
#  (852, 'David Green', 'North America', 1942),
#  (853, 'Frederik Paulsen', 'Europe', 1951),
#  (854, 'George Roberts', 'North America', 1944),
#  (856, 'Harry Triguboff', 'North America', 1933),
#  (857, 'Henry Kravis', 'North America', 1944),
#  (858, 'Joe Lewis', 'Europe', 1937),
#  (859, 'Micky Jagtiani', 'South Asia', 1952),
#  (861, 'Stein Erik Hagen', 'Europe', 1957),
#  (862, 'Walter Kwok', 'East Asia', 1951),
#  (863, 'Alfonso Romo Garza', 'Latin America', 1996),
#  (864, 'Jorge Larrea', 'Latin America', 1996),
#  (867, 'Klaus Jacobs', 'Europe', 1996),
#  (868, 'Krit Ratanarak', 'East Asia', 1947),
#  (869, 'Ayhan Sahenk', 'Middle East/North Africa', 1996),
#  (873, 'Kenneth Troutt', 'North America', 1948),
#  (874, 'Andre Kudelski', 'Europe', 2001),
#  (875, 'Clayton Mathile', 'North America', 1941),
#  (876, 'Clemmie Spangler Jr', 'North America', 1933),
#  (877, 'Donald Trump', 'North America', 1946),
#  (878, 'Eugene Melnyk', 'North America', 2001),
#  (881, 'James Jannard', 'North America', 1950),
#  (882, 'Jess Jackson', 'North America', 1930),
#  (883, 'John Arrillaga', 'North America', 1938),
#  (884, 'Kenneth Morrison', 'Europe', 1932),
#  (886, 'Lawrence Flinn Jr', 'North America', 2001),
#  (888, 'Rachman Halim', 'East Asia', 1948),
#  (889, 'Richard Peery', 'North America', 1941),
#  (890, 'Robert Rich Sr', 'North America', 1914),
#  (891, 'Roger Sant', 'North America', 2001),
#  (892, 'Rupert Johnson', 'North America', 1941),
#  (893, 'Scott McNealy', 'North America', 2001),
#  (895, 'Alfred Lerner', 'North America', 1996),
#  (897, 'Albert Frere', 'Europe', 1926),
#  (898, 'Cyrus Poonawalla', 'South Asia', 1942),
#  (900, 'Frits Goldschmeding', 'Europe', 1934),
#  (902, 'Heinz-Horst Deichmann', 'Europe', 1927),
#  (903, 'Kunio Busujima', 'East Asia', 1926),
#  (905, 'Savitri Jindal', 'South Asia', 1951),
#  (906, 'Shashi and Ravi Ruia', 'South Asia', 2014),
#  (907, 'Jose Said Saffie', 'Latin America', 1996),
#  (908, 'Jaime Said Demarfa', 'Latin America', 1996),
#  (909, 'Carlos Ardila Lulle', 'Latin America', 1996),
#  (910, 'Julio Mario Santo Domingo', 'Latin America', 1924),
#  (911, 'Hans-Werner Hector', 'Europe', 1940),
#  (913, 'Baldwin and Nikolaus Knauf', 'Europe', 1996),
#  (915, 'Chen Din Hwa', 'East Asia', 1923),
#  (916, 'Sjamsul Nursalim', 'East Asia', 1996),
#  (917, 'Abdulla bin Ahmad Al Ghurair', 'Middle East/North Africa', 2014),
#  (918, 'Ann Walton Kroenke', 'North America', 1949),
#  (919, 'Bruce Kovner', 'North America', 1945),
#  (920, 'Daniel Ziff', 'North America', 1972),
#  (921, 'Dirk Ziff', 'North America', 1965),
#  (922, 'Gwendolyn Sontheim Meyer', 'North America', 1962),
#  (923, 'Juan Roig', 'Europe', 1950),
#  (924, 'Karl Wlaschek', 'Europe', 1918),
#  (925, 'Laurence Graff', 'Europe', 1939),
#  (926, 'Liselott Persson', 'Europe', 1950),
#  (927, 'Pauline MacMillan Keinath', 'North America', 1934),
#  (928, 'Robert Ziff', 'North America', 1967),
#  (929, 'Whitney MacMillan', 'North America', 1929),
#  (930, 'Zhang Zhidong', 'East Asia', 1972),
#  (931, 'Mochtar Riady', 'East Asia', 1996),
#  (934, 'Hiroshi Takei', 'East Asia', 1996),
#  (935, 'Masafumi Miyamoto', 'East Asia', 1996),
#  (936, 'Soichiro Fukutake', 'East Asia', 1946),
#  (938, 'Abilio dos Santos Diniz', 'Latin America', 1937),
#  (939, 'Andrew McKelvey', 'North America', 2001),
#  (941, 'Dennis Bakke', 'North America', 2001),
#  (943, 'Didier Primat', 'Europe', 1945),
#  (944, 'Gary Magness', 'North America', 1954),
#  (945, 'George Mitchell', 'North America', 1920),
#  (946, 'Gil Shwed', 'Middle East/North Africa', 1968),
#  (947, 'Jackson Stephens', 'North America', 1924),
#  (949, 'Kemal Uzan', 'Middle East/North Africa', 1935),
#  (952, 'Michael Birck', 'North America', 2001),
#  (953, 'Perry Bass', 'North America', 1915),
#  (955, 'Robert Johnson', 'North America', 1947),
#  (956, 'Roberto Rocca', 'Latin America', 2001),
#  (957, 'Sanford Weill', 'North America', 1933),
#  (959, 'Tetsuro Funai', 'East Asia', 1927),
#  (960, 'Vladimir Bogdanov', 'Europe', 1952),
#  (961, 'William Morean', 'North America', 1956),
#  (964, 'Samuel LeFrak', 'North America', 1996),
#  (965, 'Leslie Wexner', 'North America', 1952),
#  (967, 'Dorrance Hill Hamilton', 'North America', 1996),
#  (969, 'Andrew Tan', 'East Asia', 1953),
#  (970, 'Arnon Milchan', 'Middle East/North Africa', 1945),
#  (972, 'Horst Paulmann', 'Latin America', 1935),
#  (976, 'Roberto and Gabriel Andrade', 'Latin America', 1996),
#  (978, 'Luiz Alberto Garcia', 'Latin America', 1996),
#  (979, 'Michael DeGroote', 'North America', 1996),
#  (980, 'Alvaro Noboa', 'Latin America', 1996),
#  (981, 'Diane Hendricks', 'North America', 1947),
#  (982, 'Mike Adenuga', 'Sub-Saharan Africa', 1954),
#  (983, 'Pierre Bellon', 'Europe', 1930),
#  (984, 'Leibbrand family', 'Europe', 1996),
#  (985, 'Reimann family', 'Europe', 1996),
#  (986, 'Conle famle', 'Europe', 1996),
#  (987, 'David Sun', 'North America', 1952),
#  (988, 'Dieter Schnabel', 'Europe', 1946),
#  (989, 'James Dyson', 'Europe', 1948),
#  (990, 'Jay Y. Lee', 'East Asia', 1969),
#  (991, 'John A. Sobrato', 'North America', 1940),
#  (992, 'John Tu', 'North America', 1941),
#  (994, 'Lynn Schusterman', 'North America', 1939),
#  (995, 'Majid Al Futtaim', 'Middle East/North Africa', 2014),
#  (996, 'Michael Herz', 'Europe', 1944),
#  (997, 'Trevor Rees-Jones', 'North America', 1952),
#  (998, 'Wolfgang Herz', 'Europe', 1951),
#  (999, 'Masakazu Shiiki', 'East Asia', 1996),
#  (1002, 'Frances Koshland Geballe', 'North America', 1996),
#  (1003, 'Josephine Haas', 'North America', 1996),
#  (1004, 'Richard Goldman', 'North America', 1996),
#  (1007, 'Abdul Al Rahman  Al Jeraisy', 'Middle East/North Africa', 2001),
#  (1008, 'Bennett Dorrance', 'North America', 1943),
#  (1009, 'Billy Joe McCombs', 'North America', 1928),
#  (1010, 'Carl Berg', 'North America', 1938),
#  (1011, 'Carlos Peralta', 'Latin America', 1952),
#  (1012, 'Christoph Blocher', 'Europe', 2001),
#  (1013, 'Enric Bernat', 'Europe', 2001),
#  (1014, 'Frank Batten', 'North America', 1927),
#  (1015, 'George Roberts', 'North America', 1945),
#  (1016, 'Harold Simmons', 'North America', 1932),
#  (1018, 'Henry Yuen', 'North America', 2001),
#  (1019, 'John Sobrato', 'North America', 1940),
#  (1021, 'Kim Magness', 'North America', 2001),
#  (1022, 'Laurance Rockefeller', 'North America', 1911),
#  (1024, 'Marius Nacht', 'Middle East/North Africa', 1966),
#  (1025, 'Mitchell Rales', 'North America', 1957),
#  (1026, 'Rem Viakhirev', 'Europe', 2001),
#  (1027, 'Richard Goldman', 'North America', 2001),
#  (1028, 'Richard Kinder', 'North America', 1947),
#  (1029, 'Richard Marriott', 'North America', 1939),
#  (1030, 'Roberto Marinho', 'Latin America', 2001),
#  (1031, 'Stelios Haji-Ioannou', 'Europe', 2001),
#  (1032, 'Steven Rales', 'North America', 1953),
#  (1035, 'Kathryn McCurry Albertson', 'North America', 1996),
#  (1036, 'Robert Galvin', 'North America', 1923),
#  (1038, 'Barbara Carlson Gage', 'North America', 1943),
#  (1039, 'Guenter Herz & Family', 'Europe', 1941),
#  (1040, 'Kelcy Warren', 'North America', 1956),
#  (1041, 'Luo Jye', 'East Asia', 1926),
#  (1042, 'Marilyn Carlson Nelson', 'North America', 1940),
#  (1046, 'Paul Mellon', 'North America', 1996),
#  (1048, 'Dan Olsson', 'Europe', 1947),
#  (1049, 'Emanuele (Lino) Saputo', 'North America', 1937),
#  (1050, 'Guo Guangchang', 'East Asia', 1967),
#  (1051, 'Lee Shin Cheng', 'East Asia', 1940),
#  (1052, 'Liang Wengen', 'East Asia', 1957),
#  (1053, 'Paul Tudor Jones, II.', 'North America', 1955),
#  (1055, 'Samvel Karapetyan', 'Europe', 1966),
#  (1056, 'Wang Chuanfu', 'East Asia', 1966),
#  (1058, 'Peter Haas Jr', 'North America', 1996),
#  (1059, 'Bemberg family', 'Latin America', 1996),
#  (1060, 'Leon Feffer', 'Latin America', 1996),
#  (1062, 'Run Run Shaw', 'East Asia', 1996),
#  (1063, 'George Wong', 'East Asia', 1996),
#  (1064, 'Dhirubhai Ambani', 'South Asia', 1996),
#  (1065, 'Kenichi Mabuchi', 'East Asia', 2003),
#  (1066, 'Akira Mori', 'East Asia', 1937),
#  (1068, 'Elizabeth Mohn', 'Europe', 1941),
#  (1069, 'Enrique Razon', 'East Asia', 1960),
#  (1070, 'Friede Springer', 'Europe', 1943),
#  (1073, 'Lin Rong San', 'East Asia', 1940),
#  (1074, 'Malcolm Glazer', 'North America', 1929),
#  (1075, 'Ralph Dommermuth', 'Europe', 1964),
#  (1076, 'Ted Lerner', 'North America', 1926),
#  (1077, 'Wang Wenyin', 'East Asia', 1968),
#  (1078, 'William Ding', 'East Asia', 1972),
#  (1079, 'Kazuo Inamori', 'East Asia', 1996),
#  (1080, 'Isono family', 'East Asia', 1996),
#  (1081, 'Renichi Takenaka', 'East Asia', 1996),
#  (1082, 'Ryusuke Kimura', 'East Asia', 1996),
#  (1083, 'Kim Suk-won', 'East Asia', 1996),
#  (1084, 'Yahaya Ahmad', 'East Asia', 1996),
#  (1085, 'Eugenio Garza Lagnera', 'Latin America', 1996),
#  (1086, 'Roberto Gonzalez Barrera', 'Latin America', 1947),
#  (1087, 'Isaac Saba Raffoul', 'Latin America', 1924),
#  (1088, 'Barbara Carlson Gage', 'North America', 1942),
#  (1090, 'Franklin Booth', 'North America', 1923),
#  (1091, 'George Lindemann', 'North America', 1937),
#  (1092, 'Gloria von Thurn und Taxis', 'Europe', 2001),
#  (1095, 'Koo Chen-fu', 'East Asia', 2001),
#  (1096, 'Marilyn Carlson Nelson', 'North America', 1939),
#  (1097, 'Mark Cuban', 'North America', 1961),
#  (1098, 'Michael Hilti', 'Europe', 1947),
#  (1101, 'Rafael del Pino', 'Europe', 1921),
#  (1102, 'Robert McNair', 'North America', 1941),
#  (1105, 'Stanley Druckenmiller', 'North America', 1954),
#  (1107, 'Stephen Case', 'North America', 1952),
#  (1108, 'Thomas Frist', 'North America', 1939),
#  (1109, 'Willi and Isolde Liebherr', 'Europe', 2001),
#  (1110, 'William Ford', 'North America', 2001),
#  (1111, 'William Kellogg', 'North America', 1944),
#  (1112, 'Juan and Carlos March', 'Europe', 1996),
#  (1113, 'Baron Hans Heinrich Thyssen-Bornemisza', 'Europe', 1996),
#  (1114, 'Chang Yung Fa', 'East Asia', 1927),
#  (1115, 'Robert Haas', 'North America', 1996),
#  (1116, 'Anthony Bamford', 'Europe', 1946),
#  (1117, 'Barry Lam', 'East Asia', 1950),
#  (1118, 'Beny Steinmetz', 'Middle East/North Africa', 1957),
#  (1119, 'Eduardo Saverin', 'Latin America', 1983),
#  (1120, 'Francisco Ivens de Sa Dias Branco', 'Latin America', 1937),
#  (1123, 'Shahid Khan', 'North America', 1951),
#  (1124, 'Hope Hill Van Beuren', 'North America', 1961),
#  (1125, 'Charlotte Colket Weber', 'North America', 1961),
#  (1126, 'Evelyn Danzig Haas', 'North America', 1996),
#  (1127, 'Ted Schwartz', 'North America', 1996),
#  (1128, 'William Ford', 'North America', 1996),
#  (1131, 'Reese Rowling', 'North America', 1996),
#  (1132, 'Arkady Rotenberg', 'Europe', 1952),
#  (1133, 'Bertil Hult', 'Europe', 1941),
#  (1134, 'Chairul Tanjung', 'East Asia', 1963),
#  (1136, 'David & Frederick Barclay', 'Europe', 1934),
#  (1137, 'Erich Kellerhals', 'Europe', 1939),
#  (1138, 'Gustaf Douglas', 'Europe', 1938),
#  (1140, 'John Morris', 'North America', 1949),
#  (1141, 'Lars Larsen', 'Europe', 1949),
#  (1142, 'Lei Jun', 'East Asia', 1970),
#  (1143, 'Randal Kirk', 'North America', 1954),
#  (1144, 'Wang Wei', 'East Asia', 2014),
#  (1145, 'Curtis LeRoy Carlson', 'North America', 1996),
#  (1148, 'Carl Lindner Jr', 'North America', 1920),
#  (1150, 'Charles Gates Jr', 'North America', 1922),
#  (1152, 'Ahmed Ali Kanoo', 'Middle East/North Africa', 1996),
#  (1153, 'Larragoiti family', 'Latin America', 1996),
#  (1154, 'Norberto Odebrecht', 'Latin America', 1996),
#  (1156, 'Nathaniel Rothschild', 'Europe', 1996),
#  (1157, 'Alfredo Harp Helu', 'Latin America', 1944),
#  (1160, 'Arthur Williams Jr', 'North America', 1943),
#  (1161, 'Arturo Moreno', 'North America', 1947),
#  (1162, 'Bradley Hughes', 'North America', 1934),
#  (1163, 'Calisto Tanzi', 'Europe', 2001),
#  (1164, 'Carlo De Benedetti', 'Europe', 2001),
#  (1165, 'Charles Munger', 'North America', 1925),
#  (1166, 'Donald Sturm', 'North America', 2001),
#  (1168, 'Francesco Micheli', 'Europe', 2001),
#  (1169, 'Germain Lamonde', 'North America', 2001),
#  (1170, 'Haim Saban', 'North America', 1945),
#  (1174, 'James Moran', 'North America', 1919),
#  (1176, 'Kenneth Langone', 'North America', 1936),
#  (1178, 'Patrick Guerrand', 'Europe', 2001),
#  (1179, 'Pierce Marshall', 'North America', 2001),
#  (1180, 'Putera Sampoerna', 'East Asia', 2001),
#  (1181, 'Richard Pratt', 'North America', 1935),
#  (1182, 'Roberto Hernandez Ramirez', 'Latin America', 2001),
#  (1183, 'Rong Yiren', 'East Asia', 2001),
#  (1184, 'Saleh Al Rajhi', 'Middle East/North Africa', 1912),
#  (1185, 'Silvio Scaglia', 'Europe', 1959),
#  (1186, 'Steven Jobs', 'North America', 1955),
#  (1188, 'Vincent Smith', 'North America', 2001),
#  (1189, 'Wallace McCain', 'North America', 1930),
#  (1190, 'William Levine', 'North America', 2001),
#  (1192, 'Bernard (Barry) Sherman', 'North America', 1942),
#  (1193, 'Daniel Och', 'North America', 1961),
#  (1194, 'Donald Trump', 'North America', 1947),
#  (1195, 'Heinz-Georg Baus', 'Europe', 1934),
#  (1196, 'John Gokongwei, Jr.', 'East Asia', 1928),
#  (1199, 'Stephen Bechtel, Jr.', 'North America', 1926),
#  (1200, 'Strwher family', 'Europe', 1996),
#  (1201, 'Werhahn family', 'Europe', 1996),
#  (1202, 'Chao Kuang-Piu', 'East Asia', 1996),
#  (1203, 'Shoul Eisenberg', 'Middle East/North Africa', 1996),
#  (1204, 'Sammy Ofer', 'Middle East/North Africa', 1996),
#  (1205, 'Otani Family', 'East Asia', 1996),
#  (1206, 'Shoichiro Toyoda', 'East Asia', 1996),
#  (1207, 'Junichi Murata', 'East Asia', 1996),
#  (1208, 'Alain Merieux', 'Europe', 1938),
#  (1209, 'Alexander Abramov', 'Europe', 1959),
#  (1210, 'Andreas von Bechtolsheim', 'Europe', 1956),
#  (1212, 'Mark Shoen', 'North America', 1952),
#  (1214, 'Odd Reitan', 'Europe', 1952),
#  (1215, 'Peter Hargreaves', 'Europe', 1947),
#  (1216, 'Steve Wynn', 'North America', 1942),
#  (1217, 'Uday Kotak', 'South Asia', 1960),
#  (1218, 'Walter Faria', 'Latin America', 1956),
#  (1219, 'William Koch', 'North America', 1941),
#  (1220, 'Halim Saad', 'East Asia', 1996),
#  (1223, 'Autrey family', 'Latin America', 1996),
#  (1224, 'Ana Maria Brescia Cafferata', 'Latin America', 1996),
#  (1225, 'Eugenio Lopez', 'East Asia', 1996),
#  (1227, 'Abdul Aziz Al-Sulaiman', 'Middle East/North Africa', 1996),
#  (1228, 'Alicia and Esther Koplowitz', 'Europe', 1996),
#  (1229, 'Henri Andre', 'Europe', 1996),
#  (1230, 'Eric Andre', 'Europe', 1996),
#  (1231, 'Boonsong Asavabhokhin', 'East Asia', 1996),
#  (1232, 'Aloys Wobben', 'Europe', 1952),
#  (1233, 'Axel Oberwelland', 'Europe', 1967),
#  (1235, 'Daniel Gilbert', 'North America', 1962),
#  (1236, 'Gong Hongjia', 'East Asia', 1965),
#  (1237, 'Guenther Fielmann', 'Europe', 1940),
#  (1238, 'Igor Kesaev', 'Europe', 1967),
#  (1239, 'Isabel dos Santos', 'Sub-Saharan Africa', 1974),
#  (1240, 'Jiang Bin', 'East Asia', 1967),
#  (1241, 'John Sall', 'North America', 1949),
#  (1242, 'Joseph Tsai', 'North America', 1964),
#  (1243, 'Karen Pritzker', 'North America', 1958),
#  (1244, 'Martin & Olivier Bouygues', 'Europe', 2014),
#  (1245, 'Michael Stoschek', 'Europe', 1948),
#  (1246, 'Murat Ulker', 'Middle East/North Africa', 1960),
#  (1247, 'Nathan Kirsh', 'Sub-Saharan Africa', 1932),
#  (1248, 'Niels Peter Louis-Hansen', 'Europe', 1948),
#  (1249, 'Ronald Lauder', 'North America', 1944),
#  (1250, 'Wu Yajun', 'East Asia', 1964),
#  (1251, 'Zhang Jindong', 'East Asia', 1964),
#  (1252, 'Zhang Xin', 'East Asia', 1966),
#  (1253, 'John Sall', 'North America', 1942),
#  (1255, 'Kenneth Tuchman', 'North America', 1996),
#  (1258, 'Randolph Hearst', 'North America', 1996),
#  (1259, 'Fred Lennon', 'North America', 1996),
#  (1260, 'Winthrop Rockefeller', 'North America', 1949),
#  (1262, 'Robert Ziff', 'North America', 1975),
#  (1265, 'Jack Taylor', 'North America', 1996),
#  (1266, "Anthony O'Reilly", 'Europe', 1937),
#  (1267, 'Archie Aldis Emmerson', 'North America', 1930),
#  (1268, 'Brian Roberts', 'North America', 2001),
#  (1270, 'David Bromilow', 'East Asia', 2001),
#  (1272, 'Edward Bass', 'North America', 1945),
#  (1273, 'Frederick Field', 'North America', 1953),
#  (1274, 'Harold Lenfest', 'North America', 2001),
#  (1275, 'Herbert Siegel', 'North America', 1928),
#  (1276, 'Jaime Augusto Zobel de Ayala', 'East Asia', 2001),
#  (1278, 'John Krehbiel Jr', 'North America', 2001),
#  (1279, 'John Marriott Jr', 'North America', 1936),
#  (1280, 'Jon Stryker', 'North America', 1959),
#  (1281, 'Joseph Jamail Jr', 'North America', 1926),
#  (1282, 'Kunio Busujima', 'East Asia', 1968),
#  (1285, 'Marc Rich', 'Europe', 1935),
#  (1286, 'Marguerite Harbert', 'North America', 1924),
#  (1287, 'Mortimer Zuckerman', 'North America', 1938),
#  (1289, 'Renato Soru', 'Europe', 2001),
#  (1290, 'Richard Scaife', 'North America', 2001),
#  ...]

# %%
metadata = MetaData()

# Tabla people
people = Table('people', metadata,
    Column('person_id', Integer, primary_key=True),
    Column('name', String, nullable=False),
    Column('location.region', String, nullable=False),
)

# Tabla companies
companies = Table('companies', metadata,
    Column('company_id', Integer, primary_key=True),
    Column('company.name', String, nullable=False),
)

# Tabla companies
companies = Table('companies', metadata,
    Column('company_id', Integer, primary_key=True),
    Column('company.name', String, nullable=False),
)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-12-47bcabbf427a> in <module>
#      17 companies = Table('companies', metadata,
#      18     Column('company_id', Integer, primary_key=True),
# ---> 19     Column('company.name', String, nullable=False),
#      20 )
#
# <string> in __new__(cls, *args, **kw)
#
# ~/miniconda3/lib/python3.7/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     126                     )
#     127
# --> 128             return fn(*args, **kwargs)
#     129
#     130         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ~/miniconda3/lib/python3.7/site-packages/sqlalchemy/sql/schema.py in __new__(cls, *args, **kw)
#     486                     "to redefine "
#     487                     "options and columns on an "
# --> 488                     "existing Table object." % key
#     489                 )
#     490             table = metadata.tables[key]
#
# InvalidRequestError: Table 'companies' is already defined for this MetaData instance.  Specify 'extend_existing=True' to redefine options and columns on an existing Table object.

# %% [markdown]
# Save to the database:

# %% [markdown]
# Test query
#
# ```
# sqlite>
#
# select count(*) from people
#     inner join positions on people."index" = positions.person_id
#     inner join companies on positions.company_id=companies."index";
#
# count(*)
# 2102
# ```
